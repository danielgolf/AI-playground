# %%
import numpy as np
import keras
import keras.layers as layers
import matplotlib.pyplot as plt
from keras.datasets import cifar10

# %%
(traini, trainl), (testi, testl) = cifar10.load_data()

# %%
plt.imshow(traini[100])
